# %%
import numpy as np
import pandas as pd
import os, pickle
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn import metrics
import sklearn.preprocessing as preprocessing
import statistics
import math

import sklearn.linear_model as lm
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV


from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
import warnings 
warnings.filterwarnings("ignore")

# %%
class DataPreparation:
    def __init__(self, outcome, features=None, categorical_features=None, one_hot_encoder=None):
        self._outcome = outcome
        self._features = features
        self._categorical_features = categorical_features
        self._one_hot_encoder = one_hot_encoder
 
    def getData(self, path, separator):
        data = pd.read_csv(path, sep = separator)
        if self._features:
            data = data[self._features]
        return data
    
    def replaceValues(self,colunas, data, tipo):
        if tipo == 'Binary':
            for coluna in colunas:
                coluna = data[coluna]
                for index in range (len(coluna)):
                    if coluna[index] >= 10:
                        coluna[index] = 1
                    else:
                        coluna[index] = 0
        elif tipo == 'FiveLevels':
            for coluna in colunas:
                coluna = data[coluna]
                for index in range (len(coluna)):
                    if coluna[index] <= 9:
                        coluna[index] = 5
                    elif coluna[index] >= 10 and coluna[index] <= 11 :
                        coluna[index] = 4
                    elif coluna[index] >= 12 and coluna[index] <= 13 :
                        coluna[index] = 3
                    elif coluna[index] >= 14 and coluna[index] <= 15 :
                        coluna[index] = 2
                    else:
                        coluna[index] = 1
        return data
    
    def getDataInfo(self,data):
        print("Number of Rows: {}\nNumber of Columns: {}".format(data.shape[0], data.shape[1]))
        print("The dataset has %d rows and %d columns " 
              % data.shape + "and has " + ("some" if data.isnull().values.any() else "no")  + " missing values.")
        return data.describe()
        
    def checkAndFillMissingValuesMode(self,data):
        features = data.columns
        for feature in features:
            if (data[feature].isnull().values.any() == True):
                print("-The column '{}', has'{}' missing values.\n"
                .format(feature, data[feature].isnull().sum()))
                data[feature].fillna(statistics.mode(data[feature]), inplace = True)
        return data
    
    def getFeaturesTypes(self,data):
        return(data.dtypes)
    
    def changeFeatureType(self,data,previousType, newType):
        for feature in data.columns:
            if ((data[feature].dtypes) == previousType):
                #for value in data[feature]:
                #value = value.astype(np.int64)
                data[feature] = data[feature].astype(np.int64)
        print(data.dtypes)
        return data

    def getBarPlots(self,data):
        plt.figure(figsize = (30, 30))
        for i in enumerate(data.columns):
            plt.subplot(int(data.columns.size/4)+1,4,i[0]+1)
            sns.countplot(i[1], data = data)
        
        
    def getCathegoricalFeatures(self,data):
        features = data.columns
        numeric_features = data._get_numeric_data().columns
        for column in data[numeric_features][:-2]:
            print("-The column '{}', has values that goes from '{}' to '{}' and is '{}' type.\n"
            .format(column, data[column].min(), data[column].max(), data[column].dtype))
            
        list_cathegorical_features = list(set(features) - set(numeric_features))
        for column in data[list_cathegorical_features][:-2]:
            print("-The column '{}' is a categorical column with values from '{}' to '{}' and is {} type"
          .format(column, data[column].min(), data[column].max(), data[column].dtype))
            
        return list_cathegorical_features
    
    def getFeaturesDescription(self,data, label):
        for col in data.columns:
            if col != label:
                data[col].describe()
    
    def CorrelationMatrix(self,data):
        plt.figure(figsize=(18,16))
        sns.heatmap(data.corr(),annot=True)
        plt.show()
        
    def Vif(self,data,label):
        thresh = 10
        independent_variables = []
        print(independent_variables)
        for col in data.columns:
            if col != label:
                independent_variables.append(col)
        for i in np.arange(0, len(data)):
            vif = [variance_inflation_factor(data[independent_variables].values,ix)
                for ix in range(data[independent_variables].shape[1])]
            maxloc = vif.index(max(vif))
            if max(vif) > thresh:
                print('vif :', vif)
                print('dropping', data[independent_variables].columns[maxloc],
                      'at index', maxloc)
                del independent_variables[maxloc]
            else:
                break

        print('Final variables :',independent_variables)
        return independent_variables
    
    def oneHotEncoding(self, data):
        if self._categorical_features:
            categorial = data[self._categorical_features]
        else:
            categorical = data.select_dtypes(exclude=np.number)
            categorical_features = categorical.columns
        if self._one_hot_encoder:
            one_hot_encoder = self._one_hot_encoder
        else:
            one_hot_encoder = preprocessing.OneHotEncoder(
                sparse=False,
                drop='first')
        categorical = one_hot_encoder.fit_transform(categorical)
        categorical_columns = one_hot_encoder.get_feature_names_out(categorical_features)
        categorical = pd.DataFrame(categorical, columns=categorical_columns)
        continuous = data.select_dtypes(include=np.number)
        data = pd.concat([categorical, continuous], axis=1)
        return data, one_hot_encoder
    
    def normalizeData(self,data,label):
        numeric_features = data.loc[:, data.columns != label].select_dtypes(include=np.number).columns.tolist()
        
        sc = preprocessing.StandardScaler()
        sc.fit(data[numeric_features])
        data[numeric_features] = sc.transform(data[numeric_features])
        return data
    
    def splitData(self, data, independent_variables, size_test):
        x, y = data[independent_variables], data.iloc[:, [-1]]
        X_train , X_test , y_train , y_test = train_test_split(x, y, test_size = size_test, random_state = 2017)
        return X_train, X_test, y_train, y_test
    
    def fit(self, X_train, y_train, algorithm):
        model = algorithm.fit(X_train, y_train)
        return model
    
    def predict(self, model, X_test):
        result = model.predict(X_test)
        return result
    
    def modelMetrics(self,model, X_test, y_test, y_test_pred):
        print('Train MAE : ',metrics.mean_absolute_error(y_test,y_test_pred))
        print('Train RMSE',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
        print('R- Squared = ',metrics.r2_score (y_test, y_test_pred))
        print("The MAE of the Model is:", metrics.mean_absolute_error(y_test, y_test_pred))
        print("Accuracy: ", metrics.accuracy_score(y_test, y_test_pred))
        print ('Test confusion matrix \n', metrics.confusion_matrix (y_test, y_test_pred))
        print ('Classification report : \n',metrics.classification_report(y_test,y_test_pred))

# %%
class SupervisedMlModels:
    def __init__(self, x_train=None, x_test=None, y_train=None, y_test=None):
        self._x_train = x_train
        self._x_test = x_test
        self._y_train = y_train
        self._y_test = y_test
        
    def hyperparameterTuning(self, model):
        if model == 'LinearRegression':
            grid = lm.LinearRegression()
        elif model == 'Svm':
            param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
            grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
        elif model == 'RandomForest':
            param_grid = {
                'bootstrap': [True],
                'max_depth': [80, 90, 100, 110],
                'max_features': [2, 3],
                'min_samples_leaf': [3, 4, 5],
                'min_samples_split': [8, 10, 12],
                'n_estimators': [100, 200, 300, 1000]
            }
            grid = GridSearchCV(estimator = RandomForestRegressor(), param_grid = param_grid, 
                                      cv = 3, n_jobs = -1, verbose = 2)
        elif model == 'DecisionTree':
            params = {
                'max_depth': [2, 3, 5, 10, 20],
                'min_samples_leaf': [5, 10, 20, 50, 100],
                'criterion': ["gini", "entropy"]
            }
            grid = GridSearchCV(estimator=DecisionTreeClassifier(random_state=42), 
                                       param_grid=params, 
                                       cv=10, n_jobs=-1, verbose=1, scoring = "accuracy")
        elif model == 'NearestNeighbour':
            k_range = list(range(1, 31))
            param_grid = dict(n_neighbors=k_range)

            grid = GridSearchCV(KNeighborsClassifier(), param_grid, 
                                cv=10, scoring='accuracy', return_train_score=False,verbose=1)
        elif model == 'NaiveBayes':
            grid = MultinomialNB();
        else:
            grid = 0
        return grid
            
        
 
    def fit(self, x_train, y_train, algorithm):
        model = algorithm.fit(x_train, y_train)
        return model
    
    def predict(self, model, x_test):
        result = np.round(model.predict(x_test))
        return result
    
    def modelMetrics(self,model, X_test, y_test, y_test_pred):
        print('Train MAE : ',metrics.mean_absolute_error(y_test,y_test_pred))
        print('Train RMSE',np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
        print('R- Squared = ',metrics.r2_score (y_test, y_test_pred))
        print("The MAE of the Model is:", metrics.mean_absolute_error(y_test, y_test_pred))
        print("Accuracy: ", metrics.accuracy_score(y_test, y_test_pred))

# %%
if __name__ == '__main__':
    path1 = 'Datasets\student-mat.csv'
    path2 = 'Datasets\student-por.csv'
    model_instance = DataPreparation(outcome = 'yes', features=None, categorical_features=None, one_hot_encoder=None)
    data_math = model_instance.getData(path1, separator = ';')
    print(data_math)
    data_por = model_instance.getData(path2, separator = ';')
    data_info_mat = model_instance.getDataInfo(data_math) 
    data_info_por = model_instance.getDataInfo(data_por)
    data_math = model_instance.checkAndFillMissingValuesMode(data_math)
    data_por = model_instance.checkAndFillMissingValuesMode(data_por)
    features_types_mat = model_instance.getFeaturesTypes(data_math)
    data_math = model_instance.changeFeatureType(data_math, 'float64', 'int64')
    dat_por = model_instance.changeFeatureType(data_por, 'float64', 'int64')
    
    data_math = model_instance.replaceValues(['G1','G2','G3'], data_math, tipo = 'FiveLevels')
    dat_por = model_instance.replaceValues(['G1','G2','G3'], dat_por, tipo = 'FiveLevels')
    
    data_math, one_hot_math = model_instance.oneHotEncoding(data_math)
    #independent_variables_math = model_instance.Vif(data_math,'G3')
    X_train_math, X_test_math, y_train_math, y_test_math = model_instance.splitData(data_math, 
                                                                     data_math.columns[data_math.columns != 'G3'],
                                                                     #independent_variables_math, 
                                                                     size_test = 0.3)
    
    data_por, one_hot_por = model_instance.oneHotEncoding(data_por)
    independent_variables_por = model_instance.Vif(data_por,'G3')
    X_train_por, X_test_por, y_train_por, y_test_por = model_instance.splitData(data_por, 
                                                                     data_por.columns[data_por.columns != 'G3'], 
                                                                     size_test = 0.3)
    
    print(X_train_por.columns != 'G3')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences    G1  G2    G3
# 0    ...      4        3    4.0     1     1      3        6   5.0   6   6.0
# 1    ...      5        3    3.0     1     1      3        4   5.0   5   6.0
# 2    ...      4        3    2.0     2     3      3       10   7.0   8  10.0
# 3    ...      3        2    2.0     1     1      5        2  15.0  14  15.0
# 4    ...      4        3    2.0     1     2      5        4   6.0  10  10.0
# ..   ...    ...      ...    ...   ...   ...    ...      ...   ...  ..   ...
# 390  ...      5        5    4.0     4     5      4       11   9.0   9   9.0
# 391  ...      2        4    5.0     3     4      2        3  14.0  16  16.0
# 392  ...      5        5    3.0     3     3      3        3  10.0   8   7.0
# 393  ...      4        4    1.0     3     4      5        0  11.0  12  10.0
# 394  ...      3        2    3.0     3     3      5        5   8.0   9   9.0
#
# [395 rows x 33 columns]
# Number of Rows: 395
# Number of Columns: 33
# The dataset has 395 rows and 33 columns and has some missing values.
# Number of Rows: 649
# Number of Columns: 33
# The dataset has 649 rows and 33 columns and has some missing values.
# -The column 'Mjob', has'1' missing values.
#
# -The column 'guardian', has'1' missing values.
#
# -The column 'paid', has'1' missing values.
#
# -The column 'goout', has'1' missing values.
#
# -The column 'G1', has'1' missing values.
#
# -The column 'G3', has'1' missing values.
#
# -The column 'address', has'1' missing values.
#
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object
# []
# vif : [2.3229956477915263, 2.371157258999501, 4.269390477700451, 1.6226119002859791, 9.499069555808353, 1.9456270132506894, 3.3124860386614166, 2.6675712659733133, 2.553585736396696, 1.8025055858773467, 10.382812718054657, 5.68037271548212, 2.2643491540622236, 1.7044697068114798, 1.3730211191220953, 1.7927045915467559, 4.5206569603690285, 1.6066560956679932, 1.2950395286306204, 2.8773147408992976, 1.173431044480026, 2.2121299996169936, 5.387005558685923, 11.548646698931272, 5.363259844719289, 1.7681038406623706, 89.09240958633393, 15.905437589215422, 11.286617357079725, 6.809457218123448, 7.98688366380578, 1.5511674499009578, 19.785507067694816, 12.529995123582939, 12.188253581794408, 6.672658025113661, 8.777026306149924, 8.041172969731956, 2.0200713193305777, 40.321676627317316, 37.536531440825904]
# dropping age at index 26
# vif : [2.2391447219232554, 2.3462289110578594, 4.024430197939019, 1.5962074055973647, 8.73173228245294, 1.9445233661484045, 3.291273321295834, 2.667469283137636, 2.544657802773433, 1.7959108564525652, 9.895943595632543, 5.458706027970543, 2.1809929564814015, 1.6896395722758002, 1.3699500441819454, 1.7740752845168224, 4.343672998846734, 1.5033714367393731, 1.285171164342565, 2.8736973912586667, 1.1703400224167184, 2.2107747358412286, 5.272909987779073, 11.250700305395533, 5.338614355233506, 1.7494861067171463, 15.677667105217944, 11.223549084054698, 6.56827481317021, 7.373785884878602, 1.5071592271862866, 18.17790144357821, 12.373854817591926, 12.117622302394468, 6.65840762520892, 8.743783321962656, 7.86173152253319, 1.9943533068725543, 38.74638219292097, 37.51462830898821]
# dropping G1 at index 38
# vif : [2.2000370321234137, 2.3461473821718744, 4.012790731685468, 1.5948383940610982, 8.688249377904576, 1.943826318877006, 3.291007011863977, 2.6646526991022323, 2.5434980921956973, 1.7952258555389666, 9.895308217431067, 5.458583374337758, 2.179835022248416, 1.6889340744869632, 1.3678368718638305, 1.773809794492437, 4.315657388214729, 1.4894624229974374, 1.2815666163256056, 2.872954446245975, 1.1685722510530585, 2.2092941715647627, 5.242821289630683, 11.228421510628745, 5.326566660240848, 1.7467551217223363, 15.676315750352398, 11.209655498494312, 6.56664974724593, 7.363009892958604, 1.50249188047342, 17.96540812841556, 12.372726893429297, 12.061124696604935, 6.638291819375911, 8.72661323494914, 7.857904925046892, 1.9941177397243, 11.67620863524577]
# dropping famrel at index 31
# vif : [2.19420419936173, 2.3290915365178253, 4.0015410033028935, 1.5888910342084446, 8.521838961343454, 1.9309371899961867, 3.2909772239093122, 2.6608990788117968, 2.5302114157806743, 1.7808744529137455, 9.602616967016816, 5.262378065949972, 2.168576039746221, 1.6865430127039127, 1.3642143512015874, 1.766835809919094, 4.30518235531526, 1.4894621073100658, 1.281496831916841, 2.868823089769021, 1.168294300014961, 2.2087185461836074, 5.209043787441664, 11.092401832824722, 5.282231628908263, 1.7466021159838139, 15.622465350451792, 11.195700127179153, 6.509019593372837, 7.344088891944267, 1.502228286293725, 12.039949369138146, 11.835697147063762, 6.635817084408588, 8.58812409678586, 7.57514180173406, 1.9939300423985515, 11.650686179964225]
# dropping Medu at index 26
# vif : [2.1941287712322195, 2.3154434816458322, 3.9869301427710773, 1.58782169670271, 8.520189661367032, 1.6617741128706793, 3.165609900172072, 2.4490344759904294, 2.056062099241881, 1.7790471413295217, 9.571111820775679, 5.262367733614143, 2.1675321538066292, 1.6859874990620611, 1.3630779569860614, 1.7596445290816085, 4.247013182072947, 1.4893601425013694, 1.2806327357286929, 2.863559194700215, 1.1600117924901883, 2.2066872367679102, 5.152380064044427, 11.044195713133654, 5.252083799326463, 1.742057780859439, 8.039233302919238, 6.488853136889222, 7.286597170385124, 1.5021515855069956, 12.02013141049133, 11.811164044715722, 6.58419437505195, 8.507390442951575, 7.562324133891929, 1.9938130808028969, 11.650627804819193]
# dropping freetime at index 30
# vif : [2.182638454270756, 2.2845277588607655, 3.983472150131815, 1.5876998270921745, 8.459957589806134, 1.6616854547653481, 3.1640990134740186, 2.4487745553846088, 2.0499154366576384, 1.7782912439195444, 9.543255127979007, 5.260287925841354, 2.1665196801172892, 1.6852421180213852, 1.3619094637277476, 1.759265396482234, 4.229894497033649, 1.4868212137038868, 1.2798313189849884, 2.860111818343928, 1.1492753204783752, 2.178842758410401, 5.145898054497406, 11.040851861197483, 5.230255370508978, 1.7387604390433757, 8.007157058959146, 6.488248953394405, 7.269550836809064, 1.494816970936335, 10.335863957762568, 6.575073019246222, 8.469416991848734, 7.442274369631701, 1.98877178637408, 11.473310779874824]
# dropping G2 at index 35
# vif : [2.05653790723697, 2.2526417574903697, 3.9587908556689975, 1.5870969690123415, 8.33073630670746, 1.6591184610478722, 3.1607575052762296, 2.4466526473983805, 2.0437495715965186, 1.7744048855740115, 9.426598828638797, 5.1543941477064, 2.1664720703030977, 1.6852389178665874, 1.3601813933566387, 1.7577214060864623, 4.140960782018032, 1.4828716114485652, 1.2294497854620319, 2.847925746562976, 1.148857584829499, 2.1738881068192746, 5.134365999660551, 10.984507209666035, 5.230251900910836, 1.7280145431031715, 8.006588578417412, 6.319922345295583, 7.268015207133692, 1.4026487068683544, 10.232434355988243, 6.558516847418922, 8.462971098290902, 7.1453358157184175, 1.915297090934875]
# dropping higher_yes at index 23
# vif : [2.0515609615676986, 2.250211545172304, 3.9164773099356376, 1.5844478659586516, 8.225262822633013, 1.634839170387702, 3.1194968278655026, 2.432116752967898, 2.033961973468552, 1.773169425602262, 9.207512575989584, 5.044884002101062, 2.1526654928832856, 1.6803240711138865, 1.3601726868520567, 1.7544039956401496, 4.102767313363898, 1.4768517593712367, 1.2212822244642798, 2.831905672039752, 1.148382904574371, 2.1707284116566723, 5.124873711775294, 5.22806856207636, 1.7267945685220742, 7.79807663005949, 6.220876976783723, 6.999175446092725, 1.3515570754095767, 10.232417671240036, 6.551321839140467, 8.460163157738585, 7.073005844055573, 1.9137729590308203]
# dropping goout at index 29
# Final variables : ['school_MS', 'sex_M', 'address_U', 'famsize_LE3', 'Pstatus_T', 'Mjob_health', 'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher', 'reason_home', 'reason_other', 'reason_reputation', 'guardian_mother', 'guardian_other', 'schoolsup_yes', 'famsup_yes', 'paid_yes', 'activities_yes', 'nursery_yes', 'internet_yes', 'romantic_yes', 'Fedu', 'traveltime', 'studytime', 'failures', 'Dalc', 'Walc', 'health', 'absences']
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]

# %%
if __name__ == '__main__':
    model_ml_math = SupervisedMlModels(x_train=None, x_test=None, y_train=None, y_test = None)
    algorithms_math = ['LinearRegression','DecisionTree','Svm','RandomForest','NearestNeighbour','NaiveBayes']
    for algorithm in algorithms_math:
        model_math = model_ml_math.hyperparameterTuning(algorithm)
        if model_math != 0:
            print('O algoritmo escolhido foi',algorithm)
            model_ml_math.fit(X_train_math, y_train_math, model_math)
            y_test_pred_math = model_ml_math.predict(model_math,X_test_math)
            model_ml_math.modelMetrics(model_math,X_test_math,y_test_math, y_test_pred_math)
            pickle.dump(model_math,open("Models/Maths/FiveLevels/"+algorithm+'.pkl','wb'))
        else:
            print("O seguinte modelo não existe")
# Out:
# O algoritmo escolhido foi LinearRegression
# Train MAE :  0.2184873949579832
# Train RMSE 0.5185629788417315
# R- Squared =  0.8581433467441514
# The MAE of the Model is: 0.2184873949579832
# Accuracy:  0.7983193277310925
# O algoritmo escolhido foi DecisionTree
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Train MAE :  0.19327731092436976
# Train RMSE 0.4936572484949417
# R- Squared =  0.8714424079868872
# The MAE of the Model is: 0.19327731092436976
# Accuracy:  0.8235294117647058
# O algoritmo escolhido foi Svm
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.446 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.455 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.455 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.436 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.491 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.455 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.564 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.473 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.309 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.482 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.473 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.455 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.473 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.709 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.357 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.309 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.482 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.473 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.455 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.473 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.564 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.582 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.625 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.655 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.582 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.709 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.764 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.564 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.339 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.327 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.482 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.473 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.455 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.473 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.564 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.582 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.571 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.582 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.509 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.589 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.582 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.691 total time=   0.0s
# Train MAE :  0.33613445378151263
# Train RMSE 0.6610406870351978
# R- Squared =  0.7694829384592461
# The MAE of the Model is: 0.33613445378151263
# Accuracy:  0.6890756302521008
# O algoritmo escolhido foi RandomForest
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# Train MAE :  0.7310924369747899
# Train RMSE 0.965801796044974
# R- Squared =  0.5079347340187752
# The MAE of the Model is: 0.7310924369747899
# Accuracy:  0.36134453781512604
# O algoritmo escolhido foi NearestNeighbour
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Train MAE :  0.6134453781512605
# Train RMSE 0.9393364366277243
# R- Squared =  0.5345328565042469
# The MAE of the Model is: 0.6134453781512605
# Accuracy:  0.5042016806722689
# O algoritmo escolhido foi NaiveBayes
# Train MAE :  0.8487394957983193
# Train RMSE 1.2400867413412742
# R- Squared =  0.1887572641931159
# The MAE of the Model is: 0.8487394957983193
# Accuracy:  0.42857142857142855

# %%
if __name__ == '__main__':
    model_ml_por = SupervisedMlModels(x_train=None, x_test=None, y_train=None, y_test = None)
    algorithms_por = ['LinearRegression','DecisionTree','Svm','RandomForest','NearestNeighbour','NaiveBayes']
    for algorithm in algorithms_por:
        model_por = model_ml_por.hyperparameterTuning(algorithm)
        if model_por != 0:
            print('O algoriportmo escolhido foi',algorithm)
            model_ml_por.fit(X_train_por, y_train_por, model_por)
            y_test_pred_por = model_ml_por.predict(model_por,X_test_por)
            model_ml_por.modelMetrics(model_por,X_test_por,y_test_por, y_test_pred_por)
            pickle.dump(model_por,open("Models/Portuguese/FiveLevels/"+algorithm+'.pkl','wb'))
        else:
            print("O seguinte modelo não existe")
# Out:
# O algoriportmo escolhido foi LinearRegression
# Train MAE :  0.27692307692307694
# Train RMSE 0.563869415688347
# R- Squared =  0.7856002837382514
# The MAE of the Model is: 0.27692307692307694
# Accuracy:  0.7384615384615385
# O algoriportmo escolhido foi DecisionTree
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Train MAE :  0.28205128205128205
# Train RMSE 0.5593035962878415
# R- Squared =  0.789058343677957
# The MAE of the Model is: 0.28205128205128205
# Accuracy:  0.7282051282051282
# O algoriportmo escolhido foi Svm
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.341 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.451 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.560 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.505 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.462 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.511 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.549 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.681 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.560 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.560 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.578 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.330 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.396 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.396 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.385 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.389 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.286 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.407 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.571 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.511 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.615 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.670 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.633 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.582 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.593 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.578 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.363 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.396 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.407 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.396 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.400 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.286 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.407 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.571 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.511 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.516 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.626 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.604 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.692 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.578 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.637 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.689 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.637 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.681 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.604 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.578 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.286 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.297 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.300 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.407 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.571 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.538 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.511 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.516 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.626 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.604 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.692 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.578 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.626 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.659 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.615 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.615 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.622 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.681 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.626 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.689 total time=   0.0s
# Train MAE :  0.28717948717948716
# Train RMSE 0.563869415688347
# R- Squared =  0.7856002837382514
# The MAE of the Model is: 0.28717948717948716
# Accuracy:  0.7230769230769231
# O algoriportmo escolhido foi RandomForest
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# Train MAE :  0.4512820512820513
# Train RMSE 0.7161148740394329
# R- Squared =  0.6541940060294378
# The MAE of the Model is: 0.4512820512820513
# Accuracy:  0.5743589743589743
# O algoriportmo escolhido foi NearestNeighbour
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# Train MAE :  0.5282051282051282
# Train RMSE 0.8070204776101108
# R- Squared =  0.560826387657386
# The MAE of the Model is: 0.5282051282051282
# Accuracy:  0.5282051282051282
# O algoriportmo escolhido foi NaiveBayes
# Train MAE :  0.6307692307692307
# Train RMSE 0.9029864978971809
# R- Squared =  0.45016846958680623
# The MAE of the Model is: 0.6307692307692307
# Accuracy:  0.4564102564102564
